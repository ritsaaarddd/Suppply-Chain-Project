# %% [markdown]
# ## Data Loading and Initial Setup
# This section handles the loading of the dataset and any initial configurations or library imports.

# %%
# Import necessary libraries
import pandas as pd

# Load dataset (adjust path if needed)
df = pd.read_csv("../data/raw/dirty_supply_chain_inventory_dataset.csv")

# Display first 5 rows
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006          55.0                    802.0
# 1     skincare  SKU1  14.843523          95.0                    736.0
# 2     haircare  SKU2  11.319683          34.0                      8.0
# 3     skincare  SKU3  61.163343          68.0                     83.0
# 4          NaN  SKU4        NaN          26.0                    871.0
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary          58.0         7.0
# 1        7460.900065                Female          53.0        30.0
# 2        9577.749626               Unknown           NaN        10.0
# 3        7766.836426            Non-binary          23.0        13.0
# 4        2686.505152            Non-binary           5.0         3.0
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %% [markdown]
# ## Initial Data Inspection
# This section examines the structure of the dataset, including column names, data types, and summary statistics.

# %%
# Check dataset structure
df.info()

# Summary statistics
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             1001 non-null   str
#  1   SKU                      1000 non-null   str
#  2   Price                    991 non-null    float64
#  3   Availability             995 non-null    float64
#  4   Number of products sold  993 non-null    float64
#  5   Revenue generated        1005 non-null   float64
#  6   Customer demographics    1003 non-null   str
#  7   Stock levels             992 non-null    float64
#  8   Lead times               1004 non-null   float64
#  9   Order quantities         982 non-null    float64
#  10  Shipping times           997 non-null    float64
#  11  Shipping carriers        999 non-null    str
#  12  Shipping costs           1017 non-null   float64
#  13  Supplier name            1007 non-null   str
# ...

# %% [markdown]
# ## Missing Values Analysis
#  This step identifies columns with missing values, which will be handled during the data cleaning phase.

# %%
# Count missing values per column
missing_values = df.isnull().sum().sort_values(ascending=False)

print("Missing Values per Column:")
print(missing_values)
# Out:
# Missing Values per Column:
# Order quantities           68
# Location                   66
# Price                      59
# Stock levels               58
# Number of products sold    57
# Defect rates               57
# Availability               55
# Shipping times             53
# Costs                      52
# Manufacturing costs        51
# Shipping carriers          51
# SKU                        50
# Routes                     49
# Product type               49
# Customer demographics      47
# Manufacturing lead time    46
# Lead times                 46
# Lead time                  45
# Revenue generated          45
# Production volumes         44
# Inspection results         44
# Transportation modes       44
# Supplier name              43
# Shipping costs             33
# dtype: int64

# %% [markdown]
#  Columns such as price, stock_levels, and defect_rates contain missing values and will require cleaning.

# %% [markdown]
# ## Duplicate Records Check
# This section checks for duplicate rows that may affect analysis accuracy.

# %%
# Count duplicate rows
duplicates = df.duplicated().sum()

print("Number of duplicate rows:", duplicates)
# Out:
# Number of duplicate rows: 124

# %% [markdown]
# Duplicate rows must be removed to ensure accurate analysis.

# %% [markdown]
# ## Categorical Data Inspection (Data Quality Check)
# This step identifies inconsistent or messy categorical values.

# %%
# Check transportation modes (example of dirty data)
df['Transportation modes'].value_counts()
# Out:
# Transportation modes
# ROad    288
# Rail    282
# air     263
# sea     173
# Name: count, dtype: int64

# %% [markdown]
# ## Key Columns for Business Analysis
# This section previews important columns used for inventory efficiency analysis.

# %%
# Preview important columns
df[['Product type', 'Stock levels', 'Number of products sold']].head()
# Out:
#   Product type  Stock levels  Number of products sold
# 0     haircare          58.0                    802.0
# 1     skincare          53.0                    736.0
# 2     haircare           NaN                      8.0
# 3     skincare          23.0                     83.0
# 4          NaN           5.0                    871.0
