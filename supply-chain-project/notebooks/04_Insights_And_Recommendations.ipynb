# %% [markdown]
# ### Key Insights
# -Some products are overstocked but have low sales
#
# -Certain transportation modes result in longer delivery times
#
# -Inventory levels do not always match demand
#
# -Data inconsistencies initially hid key issues

# %% [markdown]
# ### Business Recommendations
# -Reduce stock for slow-moving products
#
# -Optimize supplier and transportation strategies
#
# -Align inventory with demand patterns
#
# -Improve data quality processes

# %% [markdown]
# ### Conculusion
# This analysis successfully identified inefficiencies in inventory management, supplier performance,
# and demand alignment. By cleaning and analyzing the dataset, actionable insights were generated
# to support better operational decisions.
